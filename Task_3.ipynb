# %% [markdown]
# Task 3 AICP EDA Internship

# %%
# Importing necessary libraries for all tasks
import matplotlib.pyplot as plt
import pandas as pd

# Task 1: Draw a line using given axis values with suitable labels and title
# Data for the line plot
x = [1, 2, 3]
y = [2, 4, 1]

# Plotting the line
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='Line 1', color='blue')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Graph Example')
plt.legend()
plt.grid()
plt.show()

# Task 2: Plot two or more lines with legends, different widths, and colors
# Data for the lines
x = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]
y2 = [1, 4, 6, 8, 10]

# Plotting the lines
plt.figure(figsize=(8, 5))
plt.plot(x, y1, label='Prime Numbers', color='red', linewidth=2)
plt.plot(x, y2, label='Even Numbers', color='green', linewidth=4)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Lines with Legends')
plt.legend()
plt.grid()
plt.show()

# Task 3: Plot lines with markers
plt.figure(figsize=(8, 5))
plt.plot(x, y1, label='Line 1', marker='o', linestyle='-', markersize=8)
plt.plot(x, y2, label='Line 2', marker='s', linestyle='--', markersize=8)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Lines with Different Markers')
plt.legend()
plt.grid()
plt.show()

# Task 4: Horizontal bar chart of programming languages
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8.8, 7.7, 6.7]

plt.figure(figsize=(10, 6))
plt.barh(languages, popularity)
plt.xlabel('Popularity (%)')
plt.title('Programming Language Popularity')
plt.show()

# Task 5: Bar plot from DataFrame
df = pd.DataFrame({
    'a': [2, 4, 6, 8, 10],
    'b': [4, 2.3, 4.7, 2.6, 2.4],
    'c': [8.5, 4.2, 4.7, 4.8, 3.3],
    'd': [7.6, 6, 8, 6, 2],
})

df.plot(kind='bar', figsize=(10, 6))
plt.title('Bar Plot from DataFrame')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend(bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# Task 6: Pie chart of Olympic medals
medal_data = {
    'country': ['United States', 'Great Britain', 'China', 'Russia', 'Germany'],
    'gold_medal': [46, 27, 26, 19, 17]
}
df_medals = pd.DataFrame(medal_data)

plt.figure(figsize=(10, 8))
plt.pie(df_medals['gold_medal'], labels=df_medals['country'], autopct='%1.1f%%')
plt.title('Gold Medals in 2016 Summer Olympics')
plt.show()

# Task 7: Scatter plot of Math vs Science marks
math_marks = [88, 92, 80, 89, 100, 80, 60, 100, 80, 34]
science_marks = [35, 79, 79, 48, 100, 88, 32, 45, 20, 30]

plt.figure(figsize=(8, 6))
plt.scatter(math_marks, science_marks)
plt.xlabel('Math Marks')
plt.ylabel('Science Marks')
plt.title('Math vs Science Marks Comparison')
plt.grid()
plt.show()
