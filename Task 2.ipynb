# %% [markdown]
# Task 2 of AICP EDA internship

# %%
# Solving the first three questions step by step
import pandas as pd
import openpyxl 

# Q1: Create a pandas series without using a dictionary
data_q1 = [1, 4, 9, 6, 7]
index_q1 = ['a', 'x', 'c', '2', 'e']
series_q1 = pd.Series(data=data_q1, index=index_q1)
print("Q1 Output:")
print(series_q1)

# Q2: Create a pandas series using a dictionary
data_q2 = {'Bilal': 42, 'Ayesha': 38, 'Hadia': 39}
series_q2 = pd.Series(data=data_q2)
print("\
Q2 Output:")
print(series_q2)

# Q3: Create a pandas dataframe using a dictionary
data_q3 = {
    'day': ['1/1/2017', '1/2/2017', '1/3/2017', '1/4/2017', '1/5/2017', '1/6/2017'],
    'temperature': [32, 35, 28, 24, 32, 31],
    'windspeed': [6, 7, 2, 7, 4, 2],
    'event': ['Rain', 'Sunny', 'Snow', 'Snow', 'Rain', 'Sunny']
}
df_q3 = pd.DataFrame(data_q3)
print("\
Q3 Output:")
print(df_q3)

# Solving Q4 and Q5

# Q4: Replace the index of the DataFrame from Q3 with ['a', 'b', 'c', 'd', 'e', 'f']
new_index = ['a', 'b', 'c', 'd', 'e', 'f']
df_q3.index = new_index
print("Q4 Output:")
print(df_q3)

# Q5: Calculate mean, maximum, and minimum for the 'temperature' column
mean_temp = df_q3['temperature'].mean()
max_temp = df_q3['temperature'].max()
min_temp = df_q3['temperature'].min()

print("\
Q5 Output:")
print("Mean Temperature:", mean_temp)
print("Maximum Temperature:", max_temp)
print("Minimum Temperature:", min_temp)

# Import specific columns and apply all requirements from Task 6
people_df = pd.read_csv('people.csv', 
                       usecols=["First Name", "Sex", "Email", "Phone", "Job Title"],
                       skiprows=[1,5])

# Set the specified columns as index
people_df.set_index(["Sex", "Job Title"], inplace=True)

# Export to new CSV
people_df.to_csv("NewPeople.csv")

print("Updated DataFrame with new index structure:")
print(people_df.head())

# Re-attempting Task 7 with the uploaded file
# Importing only the first and last columns from sheet 1, skipping row 2, and setting row 2 as the header
samplework_df = pd.read_excel('SampleWork.xlsx', sheet_name=0, usecols=[0, -1], skiprows=[1])

# Exporting the modified sheet as a new sheet
samplework_df.to_excel('ModifiedSampleWork.xlsx', index=False)

print("Modified Excel sheet has been created and exported.")

# Creating AICP_DF as specified in Task 8
data = {
    'Name': ['Ali', 'Hifza', 'Bilal', 'Ahmed', 'Sara'],
    'Qualification': ['BSCS', 'BSSE', 'BSIT', 'BSCS', 'BSSE'],
    'Age': [21, 22, 23, 24, 25]
}
AICP_DF = pd.DataFrame(data)

# 1. Select specific columns for df1
df1 = AICP_DF[['Name', 'Qualification']]

# 2. Add Height column
AICP_DF['Height'] = [5.1, 6.2, 5.1, 5.2, 5.1]

# 3. Set Name as index
AICP_DF.set_index('Name', inplace=True)

print("Original AICP_DF with new index:")
print(AICP_DF)
print("\
df1:")
print(df1)
print("\
Row with index 'Hifza':")
print(AICP_DF.loc['Hifza'])
print("\
Row with index 3 (4th row):")
print(AICP_DF.iloc[3])
print("\
Dropping row with index 'Bilal':")
AICP_DF = AICP_DF.drop('Bilal')
print(AICP_DF)
# Out:
# Q1 Output:
# a    1
# x    4
# c    9
# 2    6
# e    7
# dtype: int64
# Q2 Output:
# Bilal     42
# Ayesha    38
# Hadia     39
# dtype: int64
# Q3 Output:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny
# Q4 Output:
#         day  temperature  windspeed  event
# a  1/1/2017           32          6   Rain
# b  1/2/2017           35          7  Sunny
# c  1/3/2017           28          2   Snow
# d  1/4/2017           24          7   Snow
# e  1/5/2017           32          4   Rain
# f  1/6/2017           31          2  Sunny
# Q5 Output:
# Mean Temperature: 30.333333333333332
# Maximum Temperature: 35
# Minimum Temperature: 24
# Updated DataFrame with new index structure:
# ...
